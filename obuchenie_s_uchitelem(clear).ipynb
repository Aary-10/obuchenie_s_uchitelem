# %% [markdown]
# <div style="background-color:#e6f0ff; padding: 15px; border-radius: 5px; border-top: 4px solid #2e8b57; margin-bottom: 10px;">
#   <p style="font-size: 1.2em; font-weight: bold; margin-bottom: 5px;"><span style="color: #007791; margin-right: 5px;">🎯</span> Общая цель проекта:</p>
#   <p style="margin-bottom: 10px;">Разработать решение для персонализации предложений постоянным клиентам интернет-магазина “В один клик” с целью увеличения их покупательской активности, основываясь на анализе данных и бизнес-моделировании.</p>
#     <ul style="margin-left: 20px; padding-left: 20px;">
#         <li style="list-style-type: disc; margin-bottom: 5px;"><strong>Промаркировать</strong> уровень финансовой активности клиентов (снизилась/прежний уровень).</li>
#         <li style="list-style-type: disc; margin-bottom: 5px;"><strong>Собрать и проанализировать</strong> данные о клиентах по группам: коммуникация, продуктовое поведение, покупательское поведение и поведение на сайте.</li>
#         <li style="list-style-type: disc; margin-bottom: 5px;"><strong>Построить модель</strong>, предсказывающую вероятность снижения покупательской активности клиента в следующие три месяца.</li>
#         <li style="list-style-type: disc; margin-bottom: 5px;"><strong>Использовать</strong> данные модели и данные о прибыльности клиентов для выделения сегментов покупателей.</li>
#         <li style="list-style-type: disc; margin-bottom: 5px;"><strong>Разработать</strong> персонализированные предложения для каждого сегмента.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color:#f0f0f0; padding: 15px; border-radius: 5px; border-top: 2px solid #2e8b57; margin-bottom: 10px;">
#   <p style="font-size: 1.2em; font-weight: bold; margin-bottom: 10px;">⚙️ Конкретные задачи:</p>
#
#   <div style="margin-bottom: 10px; margin-left: 20px; padding-left: 20px;">
#     <p style="font-weight: bold; margin-bottom: 5px;">Подготовка данных:</p>
#       <ul style="margin-left: 0; padding-left: 20px;">
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Загрузить и проверить корректность предоставленных данных (файлы market_file.csv, market_money.csv, market_time.csv, money.csv).</li>
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Провести необходимую предобработку данных.</li>
#          <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Объединить таблицы market_file.csv, market_money.csv, market_time.csv и преобразовать структуру данных по периодам.</li>
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Провести исследовательский анализ данных, отобрать клиентов с активностью не менее трех месяцев.</li>
#     </ul>
#   </div>
#
#   <div style="margin-bottom: 10px; margin-left: 20px; padding-left: 20px;">
#     <p style="font-weight: bold; margin-bottom: 5px;">Моделирование:</p>
#      <ul style="margin-left: 0; padding-left: 20px;">
#        <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Провести корреляционный анализ признаков и устранить мультиколлинеарность.</li>
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Использовать пайплайны для подготовки данных (ColumnTransformer для раздельной обработки количественных и категориальных признаков с различными кодировщиками и скейлерами).</li>
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Обучить модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression(), и SVC().</li>
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Подобрать гиперпараметры для каждой модели и выбрать лучшую, используя подходящую метрику.</li>
#       </ul>
#   </div>
#
#   <div style="margin-bottom: 10px; margin-left: 20px; padding-left: 20px;">
#      <p style="font-weight: bold; margin-bottom: 5px;">Анализ и Интерпретация:</p>
#       <ul style="margin-left: 0; padding-left: 20px;">
#           <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Оценить важность признаков для лучшей модели с помощью SHAP.</li>
#            <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Выявить наиболее и наименее значимые признаки.</li>
#         </ul>
#    </div>
#
#   <div style="margin-bottom: 10px; margin-left: 20px; padding-left: 20px;">
#     <p style="font-weight: bold; margin-bottom: 5px;">Сегментация и Персонализация:</p>
#      <ul style="margin-left: 0; padding-left: 20px;">
#       <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Выполнить сегментацию покупателей, используя результаты моделирования и данные о прибыльности.</li>
#       <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Выбрать и проанализировать целевой сегмент покупателей.</li>
#       <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Разработать персонализированные предложения для выбранного сегмента с целью увеличения его покупательской активности.</li>
#     </ul>
#   </div>
#
#   <div style="margin-left: 20px; padding-left: 20px;">
#     <p style="font-weight: bold; margin-bottom: 5px;">Выводы:</p>
#     <ul style="margin-left: 0; padding-left: 20px;">
#         <li style="list-style-type: disc; margin-bottom: 3px; line-height: 1.3;">Сделать общий вывод по результатам проекта, включая информацию о выбранном сегменте, предложенных мерах и их обоснование.</li>
#     </ul>
#   </div>
# </div>
# </div>

# %% [markdown]
# ## Загрузка данных

# %%
#!pip install numpy==1.23.1

# %%
#!pip install matplotlib==3.7.3

# %%
#установка библиотек
# !pip install -q shap 
# !pip install -q phik
# !pip install --upgrade scikit-learn==1.1.3

# !pip install matplotlib==3.5.0 -q
# Out:
# ...
#      |████████████████████████████████| 30.8 MB 2.6 MB/s eta 0:00:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...

# %%
#Подключение библиотек
import numpy as np
import pandas as pd
import sklearn
from scipy import stats as st 
import matplotlib as mpl
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (OneHotEncoder, OrdinalEncoder, LabelEncoder,
                                   StandardScaler, MinMaxScaler, RobustScaler)
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, precision_recall_curve, roc_auc_score)
from sklearn.cluster import KMeans
import phik
import shap
from IPython.display import Markdown

#константы
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %%
market_file = pd.read_csv('/datasets/market_file.csv')
market_money = pd.read_csv('/datasets/market_money.csv')
market_time = pd.read_csv('/datasets/market_time.csv')
money = pd.read_csv('/datasets/money.csv', sep=';', decimal=",")

# %% [markdown]
# ## Обзор данных

# %%
def analyze_dataframe(df, name=""):
    if name:
        print(f"Анализ данных: {name}\n{'='*30}")
    print("Информация о DataFrame:")
    df.info()
    print("\nПервые 5 строк DataFrame:")
    display(df.head())
    print("\nОписательная статистика DataFrame:")
    display(df.describe().T)

# %%
analyze_dataframe(market_file, name="market_file")
# Out:
# Анализ данных: market_file
# ...
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
# ...

# %% [markdown]
# **Вывод по обзору данных `market_file`:**
#
# <span style="color:#800080;">✓</span> Столбцы соответствуют описанию.
# <br>
# <span style="color:#800080;">✓</span> Явных пропусков не наблюдается.
# <br>
# <span style="color:#800080;">✓</span> Название столбцов оставим кириллицей, но приведем к единому "змеиному" стилю.
# <br>
# <span style="color:#800080;">✓</span> Формат данных соответствует.
# <br>
# <span style="color:#800080;">✓</span> В "Тип сервиса" есть опечатка в категории "стандартт" - исправим это в предобработке.

# %%
analyze_dataframe(market_money, name="market_money")
# Out:
# Анализ данных: market_money
# ...
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
#
# Первые 5 строк DataFrame:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# Описательная статистика DataFrame:
#           count           mean          std       min        25%       50%  \
# id       3900.0  215997.500000   375.325686  215348.0  215672.75  215997.5
# Выручка  3900.0    5025.696051  1777.704104       0.0    4590.15    4957.5
#
# ...

# %% [markdown]
# **Вывод по обзору данных `market_money`:**
#
# <span style="color:#800080;">✓</span> Столбцы соответствуют описанию.
# <br>
# <span style="color:#800080;">✓</span> Явных пропусков не наблюдается.
# <br>
# <span style="color:#800080;">✓</span> Название столбцов оставим кириллицей, но приведем к единому "змеиному" стилю.
# <br>
# <span style="color:#800080;">✓</span> Формат данных соответствует.
# <br>
# <span style="color:#800080;">✓</span> Видим, что есть выручка с показателем 0 и максимальная выручка 106862.2 тоже выглядит подозрительно, проверим показатель в исследовательском анализе.

# %%
analyze_dataframe(market_time, name="market_time")
# Out:
# Анализ данных: market_time
# ...
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
#
# Первые 5 строк DataFrame:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
# Описательная статистика DataFrame:
#         count           mean         std       min        25%       50%  \
# id     2600.0  215997.500000  375.349754  215348.0  215672.75  215997.5
# минут  2600.0      13.336154    4.080198       4.0      10.00      13.0
#
#              75%       max
# id     216322.25  216647.0
# ...

# %% [markdown]
# **Вывод по обзору данных `market_time`:**
#
# <span style="color:#800080;">✓</span> Столбцы соответствуют описанию.
# <br>
# <span style="color:#800080;">✓</span> Явных пропусков не наблюдается.
# <br>
# <span style="color:#800080;">✓</span> Название столбцов оставим кириллицей, но приведем к единому "змеиному" стилю.
# <br>
# <span style="color:#800080;">✓</span> Формат данных соответствует.
# <br>
# <span style="color:#800080;">✓</span> В столбце "Период" есть опечатка в категории "предыдцщий_месяц " - исправим это в предобработке.

# %%
analyze_dataframe(money, name="money")
# Out:
# Анализ данных: money
# ...
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
#
# Первые 5 строк DataFrame:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# Описательная статистика DataFrame:
#           count           mean         std        min        25%         50%  \
# id       1300.0  215997.500000  375.421985  215348.00  215672.75  215997.500
# Прибыль  1300.0       3.996631    1.013722       0.86       3.30       4.045
#
#                75%        max
# id       216322.25  216647.00
# Прибыль       4.67       7.43

# %% [markdown]
# **Вывод по обзору данных `money`:**
#
# <span style="color:#800080;">✓</span> Столбцы соответствуют описанию.
# <br>
# <span style="color:#800080;">✓</span> Явных пропусков не наблюдается.
# <br>
# <span style="color:#800080;">✓</span> Название столбцов оставим кириллицей, но приведем к единому "змеиному" стилю.
# <br>
# <span style="color:#800080;">✓</span> Формат данных соответствует.

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#
# ### <span style="color:#8B008B"> Вывод по загрузке данных</span>
#
# <span style="font-size: 1em;">Данные в целом соответствуют описанию и пригодны для дальнейшего анализа. Во всех четырех файлах: <code>market_file</code>, <code>market_money</code>, <code>market_time</code> и <code>money</code> столбцы соответствуют описанию, не обнаружено явных пропусков, и формат данных в целом корректен.</span>
#
# <span style="font-size: 1.2em; font-weight: bold;">Требуется предобработка данных:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Наименование столбцов:</span> <span style="font-size: 1em;">Необходимо привести названия столбцов всех четырех таблиц к единому "змеиному" стилю.</span></li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Опечатки:</span> <span style="font-size: 1em;">В таблицах <code>market_file</code> и <code>market_time</code> были обнаружены опечатки в категориях "Тип сервиса" ( стандартт ) и "Период" ( предыдцщий_месяц ), которые необходимо исправить.</span></li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Аномальные значения:</span> <span style="font-size: 1em;">В таблице <code>market_money</code> обнаружена нулевая выручка и подозрительно большая максимальная выручка, которые требуют проверки и анализа в рамках исследовательского анализа данных.</span></li>
#     </ul>
# <br>
# <span style="font-size: 1.2em; font-weight: bold;">Дальнейшие шаги:</span>
# <br>
# <span style="font-size: 1em;">На следующем этапе необходимо выполнить предобработку данных, включая исправление названий столбцов и опечаток, а также проверить аномальные значения, прежде чем приступать к исследовательскому анализу и дальнейшим этапам работы.</span>
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка столбцов

# %%
def normalize_col_names(col_names):
    return [col.lower().replace(' ', '_') for col in col_names]

market_file.columns = normalize_col_names(market_file.columns)
market_money.columns = normalize_col_names(market_money.columns)
market_time.columns = normalize_col_names(market_time.columns)
money.columns = normalize_col_names(money.columns)

print("market_file columns:", market_file.columns)
print("market_money columns:", market_money.columns)
print("market_time columns:", market_time.columns)
print("money columns:", money.columns)
# Out:
# market_file columns: Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')
# market_money columns: Index(['id', 'период', 'выручка'], dtype='object')
# market_time columns: Index(['id', 'период', 'минут'], dtype='object')
# money columns: Index(['id', 'прибыль'], dtype='object')

# %% [markdown]
# *Обработка столбцов выполнена*, теперь будет удобнее работать с данными

# %% [markdown]
# ### Явные дубликаты

# %%
def handle_duplicates(df, df_name):
    duplicates = df.duplicated()
    num_duplicates = duplicates.sum()
    if num_duplicates > 0:
        print(f"Обнаружено {num_duplicates} явных дубликатов в {df_name}.")
        df.drop_duplicates(inplace=True)
        print(f"Дубликаты удалены из {df_name}.")
    else:
        print(f"Явных дубликатов не обнаружено в {df_name}.")


# Обработка дубликатов
handle_duplicates(market_file, "market_file")
handle_duplicates(market_money, "market_money")
handle_duplicates(market_time, "market_time")
handle_duplicates(money, "money")


# Вывод количества строк после обработки
print("\nРазмер DataFrame после обработки дубликатов:")
print(f"market_file: {market_file.shape[0]} строк")
print(f"market_money: {market_money.shape[0]} строк")
print(f"market_time: {market_time.shape[0]} строк")
print(f"money: {money.shape[0]} строк")
# Out:
# Явных дубликатов не обнаружено в market_file.
# Явных дубликатов не обнаружено в market_money.
# Явных дубликатов не обнаружено в market_time.
# Явных дубликатов не обнаружено в money.
#
# Размер DataFrame после обработки дубликатов:
# market_file: 1300 строк
# market_money: 3900 строк
# market_time: 2600 строк
# money: 1300 строк

# %% [markdown]
# *Явных дубликатов* во всех 4 датафреймов не обнаружилось

# %% [markdown]
# ### Неявные дубликаты

# %%
def get_unique_values(data, name):
    if isinstance(data, pd.DataFrame):
        for column in data.columns:
            if data[column].dtype == 'object': 
                unique_values = data[column].unique()
                print(f"Уникальные значения в {name} (столбец '{column}'): {unique_values}")
    else:
        print(f"Неподдерживаемый тип данных для {name} или столбец не строкового типа.")

get_unique_values(market_file, 'market_file')
get_unique_values(market_money, 'market_money')
get_unique_values(market_time, 'market_time')
get_unique_values(money, 'money')
# Out:
# Уникальные значения в market_file (столбец 'покупательская_активность'): ['Снизилась' 'Прежний уровень']
# Уникальные значения в market_file (столбец 'тип_сервиса'): ['премиум' 'стандартт' 'стандарт']
# Уникальные значения в market_file (столбец 'разрешить_сообщать'): ['да' 'нет']
# Уникальные значения в market_file (столбец 'популярная_категория'): ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
# Уникальные значения в market_money (столбец 'период'): ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
# Уникальные значения в market_time (столбец 'период'): ['текущий_месяц' 'предыдцщий_месяц']

# %%
market_file['тип_сервиса'] = market_file['тип_сервиса'].replace('стандартт', 'стандарт')
market_file['популярная_категория'] = market_file['популярная_категория'].replace('Косметика и аксесуары', 'Косметика и аксессуары')
print(market_file['тип_сервиса'].unique())
print(market_file['популярная_категория'].unique())

market_time['период'] = market_time['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')
print(market_time['период'].unique())
# Out:
# ['премиум' 'стандарт']
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксессуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
# ['текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# Обнаружены и исправлены опечатки: в столбце ‘тип_сервиса’ (market_file), 'популярная_категория' (market_file) и в столбце ‘период’ (market_time)

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#
# ### <span style="color:#8B008B">Вывод по предобработке данных</span>
#
# <span style="font-size: 1em;">После проведения предобработки данных, можно отметить, что данные готовы к дальнейшей работе. Обработка отдельных столбцов завершена, что облегчает работу с информацией.</span>
#
# <span style="font-size: 1.2em; font-weight: bold;">Результаты предобработки:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Дубликаты:</span> <span style="font-size: 1em;">Явных дубликатов во всех четырех датафреймах (<code>market_file</code>, <code>market_money</code>, <code>market_time</code> и <code>money</code>) не обнаружено.</span></li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Опечатки:</span> <span style="font-size: 1em;">В наборах данных <code>market_file</code> и <code>market_time</code> были обнаружены и исправлены опечатки в столбцах 'тип_сервиса', 'популярная_категория' и 'период' соответственно.</span></li>
#     </ul>
# <br>
# <span style="font-size: 1.2em; font-weight: bold;">Дальнейшие шаги:</span>
# <br>
# <span style="font-size: 1em;">С учетом завершенной предобработки, данные готовы к дальнейшему анализу. На следующем этапе можно переходить к исследовательскому анализу и дальнейшим этапам работы.</span>
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %%
def num_col(df, x, hue=None, bins=20, xlim=None,
              xlabel='', ylabel='', legend_title='',
              title='', figsize=(16, 7), palette="viridis"):
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
    if df[x].dtype == 'object' or len(df[x].unique()) < 10:
        ax = sns.countplot(data=df, x=x, hue=hue, ax=axes[0], palette=palette)
        for i, p in enumerate(ax.patches):
            height = p.get_height()
            axes[0].text(p.get_x() + p.get_width() / 2.,
                        height + 3,
                        height,
                        ha="center")
        axes[0].set_title('Столбчатая диаграмма', pad=10, fontsize=14)
    else:
        sns.histplot(data=df, x=x, hue=hue, bins=bins, kde=True, ax=axes[0], palette=palette)
        axes[0].grid(True)
        axes[0].set_title('Гистограмма', pad=10, fontsize=14)

    if xlim:
        axes[0].set_xlim(xlim)
    axes[0].set_xlabel(xlabel, labelpad=13, fontsize=12)
    axes[0].set_ylabel(ylabel, labelpad=13, fontsize=12)
    if hue:
        legend = axes[0].get_legend()
        if legend:
            legend.set_title(legend_title)
            
    sns.boxplot(data=df, x=x, y=hue, ax=axes[1], palette=palette)
    axes[1].set_title('Ящик с усами', pad=10, fontsize=14)
    axes[1].set_xlabel(xlabel, labelpad=13, fontsize=12)
    axes[1].set_ylabel(legend_title.lower(), labelpad=13, fontsize=12)
    axes[1].tick_params(axis='y', rotation=45)
    axes[1].grid(True)
    
    fig.suptitle(title, fontsize=18)
    
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()

# %%
def cat_plots(df, column, hue, legend_title='', title='', figsize=(16, 7), colors=None):
    if len(df[hue].unique()) != 2:
        raise ValueError("Столбец 'hue' должен содержать ровно два уникальных значения.")

    def captions(pct, allvalues):
        absolute = round(pct / 100. * np.sum(allvalues))
        return f'{pct:.1f}%\n({absolute})'

    groups = df[hue].unique()
    data = [df[df[hue] == group][column].value_counts() for group in groups]

    if colors is None:
        colors = [plt.cm.tab10.colors[:len(data[0])], 
                  plt.cm.tab10.colors[len(data[0]):len(data[0]) + len(data[1])]]

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=figsize)

    for i, (ax, group, counts, color_list) in enumerate(zip(axes, groups, data, colors)):
        wedges, texts, autotexts = ax.pie(counts,
                                          autopct=lambda pct: captions(pct, counts),
                                          explode=[0.05] * len(counts),
                                          colors=color_list,
                                          textprops={'fontsize': 12, 'color': 'white'})
        ax.legend(wedges, counts.index.tolist(),
                  title=legend_title,
                  loc='center left',
                  bbox_to_anchor=(1, 0.5),
                  fontsize=12)
        ax.set_title(group, pad=10, fontsize=14)
        plt.setp(autotexts, size=12)

    fig.suptitle(title, fontsize=18)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()

# %%
num_col_market_file = ['маркет_актив_6_мес', 
                  'маркет_актив_тек_мес', 
                  'длительность', 
                  'акционные_покупки',
                  'средний_просмотр_категорий_за_визит',
                  'неоплаченные_продукты_штук_квартал', 
                  'ошибка_сервиса', 
                  'страниц_за_визит']
num_col_market_money = ['выручка']
num_col_market_time = ['минут']
num_col_money = ['прибыль']

# %%
cat_col_market_file = ['покупательская_активность', 
                  'тип_сервиса', 
                  'разрешить_сообщать', 
                  'популярная_категория']

# %% [markdown]
# ### Коммуникации с клиентом

# %%
cat_plots(df=market_file, column='тип_сервиса', hue='покупательская_активность', legend_title='Тип сервиса', title='Распределение типов сервиса по активности',
          figsize=(10, 5), colors=[['red', 'green', 'blue'], ['red', 'green', 'blue']])

# %% [markdown]
# **Распределение типов сервиса по активности**
#
# **Сравнение групп:**
#
# **Снизилась активность:**
# *   Доля "стандарт" сервиса составляет **65.9%** (328 пользователей).
# *   Доля "премиум" сервиса составляет **34.1%** (170 пользователей).
#
# **Прежний уровень активности:**
# *   Доля "стандарт" сервиса составляет **74.3%** (596 пользователей).
# *   Доля "премиум" сервиса составляет **25.7%** (206 пользователей).
#
# **Основные выводы:**
#
# *   **Снижение активности:** При снижении активности, процент пользователей премиум-сервиса увеличивается, при этом процент пользователей стандартного сервиса уменьшается. Возможно, некоторые пользователи премиум-сервиса снизили активность по каким-либо причинам.
# *   **Прежний уровень активности:** У пользователей, сохранивших прежний уровень активности, наблюдается обратная ситуация: большая часть (74.3%) выбирают стандартный сервис, а премиум-сервисом пользуются 25.7%.
# *   Пользователи премиум-сервиса менее лояльны чем пользователи стандартного сервиса, так как они более склонны к снижению активности.
# *   Больше всего клиентов используют стандартный сервис, независимо от активности.
#
# **Предположения:**
#
# *   Возможно, премиум-сервис ориентирован на более активных пользователей, но те, кто снижает свою активность, более вероятно, уже пользовались премиум-сервисом.
# *   Стандартный сервис более распространен, так как имеет меньшую стоимость и, вероятно, более широкий охват аудитории.
#
# **Рекомендации:**
#
# *   Следует изучить причины, почему пользователи премиум-сервиса снижают свою активность, и что можно сделать для их удержания.
# *   Необходимо провести дополнительный анализ для понимания различий в моделях поведения пользователей разных сервисов и разработать более эффективные стратегии привлечения и удержания.

# %%
cat_plots(df=market_file, column='разрешить_сообщать', hue='покупательская_активность', legend_title='Разрешение на рассылку', title='Распределение резрешения на рассылку',
          figsize=(10, 5), colors=[['red', 'green', 'blue'], ['red', 'green', 'blue']])

# %% [markdown]
# **Распределение разрешения на рассылку**
#
# **Общие наблюдения:**
#
# *   На обеих диаграммах категория "да" занимает большую часть круга, что говорит о ее преобладании над категорией "нет".
# *   Общее количество элементов на левом графике меньше чем на правом.
#
# **Сравнение групп:**
#
# *   Процентное соотношение "да" и "нет" практически идентично для обеих групп. Разница менее 1 процентного пункта.
# *   В группе "Прежний уровень" общее количество единиц значительно больше, чем в группе "Снизилась" (802 против 498), и, следовательно, и абсолютные значения по обоим категориям выше.

# %%
num_col(df=market_file, x='маркет_актив_6_мес', hue='покупательская_активность',
           xlabel='маркет_актив_6_мес', ylabel='Количество', legend_title='Активность',
           title='Распределение маркет_актив_6_мес', figsize=(10,5), palette="viridis")

# %% [markdown]
# Маркетинговые коммуникации (6 мес.)
#
# | Аспект     | Описание                                                                            |
# |------------|-------------------------------------------------------------------------------------|
# | Симметрия  | Распределение более симметрично у пользователей со сниженной активностью.             |
# | Средние    | Обе группы имеют средние значения около 4.                                          |
# | Медианы    | Медиана выше у пользователей с прежней активностью (4.4), чем у сниженной (3.9).  |
# | Выбросы    | Присутствуют значения за пределами размаха, удаление не требуется.                  |

# %%
num_col(df=market_file, x='маркет_актив_тек_мес', hue='покупательская_активность',
           xlabel='маркет_актив_тек_мес', ylabel='Количество', legend_title='Активность',
           title='Распределение маркет_актив_тек_мес', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Маркетинговые коммуникации (1 мес.)**
#
# | Аспект     | Описание                                                                                             |
# |------------|------------------------------------------------------------------------------------------------------|
# | Симметрия  | Распределение коммуникаций более симметрично для пользователей со сниженной покупательской активностью, чем с прежней. |
# | Средние    | В обеих группах преобладает количество маркетинговых коммуникаций, равное 4.                                  |
# | Медианы    | Обе группы имеют одинаковую медиану количества маркетинговых коммуникаций - 4.                                 |
# | Размах     | Диапазон количества коммуникаций одинаков для обеих групп: от 3 до 5.                                    |

# %%
activities = market_file['покупательская_активность'].unique()
for activity in activities:
    print(f"Статистика для группы: {activity}")
    subset = market_file[market_file['покупательская_активность'] == activity]
    display(pd.DataFrame(subset['длительность'].describe()).T)
    print("-" * 50)
num_col(df=market_file, x='длительность', hue='покупательская_активность',
           xlabel='Кол-во дней', ylabel='Количество', legend_title='Активность',
           title='Распределение дней с момента регистрации', figsize=(10,5), palette="viridis")
# Out:
# Статистика для группы: Снизилась
#               count        mean         std    min    25%    50%    75%  \
# длительность  498.0  619.883534  239.940818  110.0  449.0  634.5  811.0
#
#                  max
# длительность  1079.0
# --------------------------------------------------
# Статистика для группы: Прежний уровень
#               count        mean         std    min    25%    50%     75%  \
# длительность  802.0  590.730673  255.330179  121.0  382.5  590.0  798.75
#
#                  max
# длительность  1061.0
# --------------------------------------------------

# %% [markdown]
# **Количество дней с момента регистрации**
#
# | Аспект           | Описание                                                                                                    |
# |-------------------|-------------------------------------------------------------------------------------------------------------|
# | Распределение    | Длительность истории имеет несколько пиков в распределении у обеих групп пользователей, с пиками около 500 и 800 дней. |
# | Диапазон значений | Длительность истории варьируется от 110 до 1079 дней                                                       |
# | Медианы           | Пользователи со сниженной активностью зарегистрированы дольше (медиана — 620 дней), чем с прежней (медиана — 590 дней).   |
# | Выбросы           | Выбросы в обеих группах не обнаружены.                                                                        |

# %% [markdown]
# **Вывод по анализу коммуникации с клиентом**
#
# **Общие наблюдения:**
#
# *   **Сервис:** Большинство клиентов, независимо от уровня активности, предпочитают стандартный сервис. Однако, пользователи премиум сервиса более склонны к снижению активности.
# *   **Рассылка:** Подавляющее большинство клиентов согласны на рассылку. Процент согласных на рассылку почти одинаков в обеих группах (с прежним и сниженным уровнем активности).
# *   **Маркетинг (6 мес):** Распределение маркетинговых коммуникаций за 6 месяцев более симметрично для пользователей со сниженной активностью. Медиана количества коммуникаций выше у пользователей с прежней активностью.
# *   **Маркетинг (1 мес):** Распределение маркетинговых коммуникаций за 1 месяц более симметрично у пользователей со сниженной активностью. Среднее и медиана количества коммуникаций одинаковы в обеих группах. Диапазон количества коммуникаций одинаков.
# *   **Длительность истории:** Пользователи со сниженной активностью в среднем зарегистрированы дольше, чем пользователи с прежним уровнем активности. У обеих групп есть несколько пиков в распределении длительности истории.
#
# **Основные выводы и рекомендации:**
#
# *   **Премиум-сервис:** Пользователи премиум-сервиса демонстрируют меньшую лояльность и склонны к снижению активности. Требуется более глубокий анализ причин этого явления и разработка мер по удержанию. Возможно, стоит пересмотреть преимущества и ценообразование премиум-сервиса.
# *   **Стандартный-сервис:** Стандартный сервис остается более популярным, вероятно, из-за более низкой стоимости и широкой доступности. Необходимо продолжать поддерживать качество и доступность данного сервиса.
# *   **Рассылка:** Высокая доля согласившихся на рассылку дает возможность использовать ее как канал взаимодействия с клиентами.
# *   **Маркетинг:** Различия в распределении маркетинговых коммуникаций между группами пользователей могут указывать на различные модели их поведения. Требуется дополнительный анализ для понимания, какие стратегии маркетинга являются более эффективными для каждой группы.
# *   **Длительность истории:** Тот факт, что пользователи со сниженной активностью в среднем зарегистрированы дольше, может указывать на то, что со временем интерес к сервису ослабевает. Следует изучить причины, по которым клиенты со стажем снижают свою активность, и выработать меры по повышению их вовлеченности.

# %% [markdown]
# ### Продуктовое поведение

# %%
cat_plots(df=market_file, column='популярная_категория', 
          hue='покупательская_активность', 
          legend_title='Категории', 
          title='Распределение популярных категорий',
          figsize=(19, 5),
          colors=[['#7d1e1e', '#1e7d7d', '#1e3d7d', '#7d7d1e', '#7d1e7d', '#1e7d1e'], 
                  ['#7d1e1e', '#1e7d7d', '#1e3d7d', '#7d7d1e', '#7d1e7d', '#1e7d1e']])

# %% [markdown]
# **Распределение категорий по группам**
#
# **Сравнение групп:**
#
# **Снизилась активность:**
# *   Наибольшую долю занимают "Товары для детей" (29.3%, 146 пользователей), затем "Косметика и аксессуары" (21.1%, 105 пользователей) и "Домашний текстиль" (20.5%, 102 пользователя).
# *   Наименьшую долю занимает "Мелкая бытовая техника и электроника" (5.4%, 27 пользователей).
#
# **Прежний уровень активности:**
# *   Наибольшую долю занимают "Товары для детей" (22.9%, 184 пользователя), "Домашний текстиль" (18.6%, 149 пользователей)
# *   Наименьшую долю занимает "Кухонная посуда" (9%, 72 пользователя).
#
# **Основные выводы:**
#
# *   **Снижение активности:** Пользователи, которые снизили свою активность, чаще покупают товары для детей, косметику и аксессуары. Возможно, эти категории товаров являются более "спонтанными" или "частыми покупками" и на них меньше влияет общее снижение активности.
# *   **Прежний уровень активности:** Пользователи, сохранившие прежний уровень активности, имеют более равномерное распределение по категориям. Однако, категория "Мелкая бытовая техника и электроника" значительно увеличилась. Возможно, эта категория предполагает более обдуманные и целенаправленные покупки.
# *   **Различия в предпочтениях:** Существуют заметные различия в предпочтениях категорий между группами с разным уровнем активности. Это может быть связано с разными потребностями или мотивацией к покупкам.
# *   Категория "Товары для детей" остаётся популярной в обеих группах, хоть ее доля и снижается при сохранении активности пользователей. Это может говорить о ее стабильном спросе, независимо от общей активности пользователей.
#
# **Предположения:**
#
# *   Возможно, снижение активности коррелирует с тем, что пользователи совершают более "обыденные" и спонтанные покупки, такие как товары для детей и косметику.
# *   Сохранение активности может указывать на более обдуманные и целенаправленные покупки.
# *   Кухонная посуда менее востребована при сохранении активности.

# %%
num_col(df=market_file, x='средний_просмотр_категорий_за_визит', hue='покупательская_активность',
           xlabel='Кол-во просмотренных категорий за визит', ylabel='Количество', legend_title='Активность',
           title='Распределение просмотра категорий за визит', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Средний просмотр категорий за визит**
#
# | Аспект                | Описание                                                                                                                            |
# |-----------------------|-------------------------------------------------------------------------------------------------------------------------------------|
# | Симметрия             | Распределение среднего количества просмотренных категорий за визит более симметрично у пользователей с прежним уровнем покупательской активности. |
# | Наиболее частые значения | У пользователей с прежним уровнем покупательской активности наиболее частое среднее количество просмотренных категорий составляет 3 и 4, в то время как у пользователей со сниженным уровнем – 2. |
# | Диапазон значений      | Диапазон количества просмотренных категорий за визит одинаков для обеих групп: от 1 до 6.                                               |
# | Медианы               | Пользователи с прежним уровнем покупательской активности просматривают в среднем в 2 раза больше категорий за визит (медиана — 4), чем пользователи со сниженным уровнем (медиана — 2).       |

# %%
num_col(df=market_file, x='неоплаченные_продукты_штук_квартал', hue='покупательская_активность',
           xlabel='Число неоплаченных товаров', ylabel='Количество', legend_title='Активность',
           title='Распределение неоплаченных товаров в корзине за квартал', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Неоплаченные товары в корзине за квартал**
#
# | Аспект                  | Описание                                                                                                                                                            |
# |-------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Симметрия               | Распределение количества неоплаченных продуктов в корзине более симметрично у пользователей со сниженным уровнем покупательской активности.                            |
# | Наиболее частые значения| У пользователей со сниженным уровнем покупательской активности наиболее часто встречается количество неоплаченных продуктов от 2 до 5, в то время как у пользователей с прежним уровнем – 1. |
# | Диапазон значений       | Минимальное количество неоплаченных продуктов в корзине одинаково для обеих групп и равно 0. Максимальное количество неоплаченных продуктов в корзине у пользователей со сниженным уровнем равно 10, а у пользователей с прежним уровнем – 8.  |
# | Медианы                 | Пользователи с прежним уровнем покупательской активности имеют в среднем в 2 раза меньше неоплаченных продуктов в корзине (медиана — 2), чем пользователи со сниженным уровнем (медиана — 4). |

# %%
num_col(df=market_file, x='акционные_покупки', hue='покупательская_активность',
           xlabel='Доля покупок по акции', ylabel='Количество', legend_title='Активность',
           title='Распределение акционных покупок', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Акционные покупки**
#
# | **Аспект**            | Описание                                                                                                                                                                                                 |
# |-----------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Распределение**      |  Распределение доли покупок по акциям для пользователей с прежним уровнем активности имеет более выраженный пик около 0.2, а для пользователей со сниженной активностью распределение бимодальное, с пиками около 0.2 и 1.0. |
# | **Медианы**            |  Медианное значение доли покупок по акциям у пользователей с прежним уровнем активности ниже (0.2), чем у пользователей со сниженной активностью (0.3).                                                    |
# | **Межквартильный размах**|  Межквартильный размах для пользователей с прежним уровнем активности значительно меньше, чем для пользователей со сниженной активностью, что указывает на более концентрированные значения доли покупок по акциям. |
# | **Выбросы**            |  У пользователей с прежним уровнем активности присутствуют выбросы, расположенные выше основного диапазона значений, в то время как у пользователей со сниженной активностью выбросы отсутствуют.               |

# %% [markdown]
# **Вывод по продуктовому поведению**
#
# **Общие наблюдения:**
#
# *   Пользователи были разделены на две группы: "снизившие активность" и "сохранившие прежний уровень активности".
# *   Заметны различия в предпочтениях категорий, среднем количестве просмотренных категорий за визит, количестве неоплаченных товаров в корзине и доле акционных покупок между группами.
#
# **Распределение категорий:**
#
# *   **Снижение активности:** Покупки в основном сосредоточены на товарах для детей (29.3%), косметике и аксессуарах (21.1%) и домашнем текстиле (20.5%). "Мелкая бытовая техника и электроника" - наименее популярна (5.4%).
# *   **Прежний уровень активности:** Покупки равномернее распределены, лидируют "Товары для детей" (22.9%) и "Домашний текстиль" (18.6%). "Кухонная посуда" - наименее популярна (9%).
# *   **Тенденции:** Пользователи со сниженной активностью чаще покупают товары более спонтанного характера. Сохранившие активность – более обдуманные, особенно заметен рост покупок "Мелкой бытовой техники и электроники". "Товары для детей" популярны в обеих группах.
#
# **Средний просмотр категорий за визит:**
#
# *   **Снижение активности:** Среднее количество просмотренных категорий за визит - 2.
# *   **Прежний уровень активности:** Среднее количество просмотренных категорий за визит - 4 (в 2 раза больше).
# *   **Тенденции:** Пользователи с прежним уровнем активности более склонны к изучению ассортимента.
#
# **Неоплаченные товары в корзине:**
#
# *   **Снижение активности:** Медианное количество неоплаченных товаров - 4.
# *   **Прежний уровень активности:** Медианное количество неоплаченных товаров - 2.
# *   **Тенденции:** Пользователи со сниженной активностью чаще оставляют товары в корзине неоплаченными.
#
# **Акционные покупки:**
#
# *   **Снижение активности:** Доля акционных покупок имеет бимодальное распределение, с пиками около 0.2 и 1.0. Медиана - 0.3
# *   **Прежний уровень активности:** Доля акционных покупок имеет пик около 0.2. Медиана - 0.2
# *   **Тенденции:** Пользователи со сниженной активностью более склонны к акционным покупкам.
#
# **Общий вывод:**
#
# Снижение покупательской активности коррелирует с более спонтанными покупками, меньшим просмотром категорий и большим количеством неоплаченных товаров в корзине, а также большей склонностью к акционным покупкам. Пользователи, сохранившие прежний уровень, демонстрируют более обдуманное покупательское поведение, с более широким изучением ассортимента и меньшим количеством брошенных корзин.

# %% [markdown]
# ### Поведение на сайте

# %%
num_col(df=market_time, x='минут',
           xlabel='Время, проведенное на сайте', ylabel='Количество', legend_title='Активность',
           title='Распределение времени, проведенное на сайте', figsize=(10,5), palette="viridis")

# %%
pivot_table = market_time.groupby('период')['минут'].agg(['sum'])
pivot_table = pivot_table.round(0)
pivot_table = pivot_table.sort_values(by='sum', ascending=True)
print("Сводная таблица:")
print(pivot_table)

plt.figure(figsize=(8, 4))
sns.barplot(x=pivot_table.index, y=pivot_table['sum'], palette="viridis")
plt.xlabel('Период')
plt.ylabel('Время, проведенное на сайте')
plt.title('Распределение времени по периодам')
plt.grid(True)
plt.show()
# Out:
# Сводная таблица:
#                     sum
# период
# текущий_месяц     17166
# предыдущий_месяц  17508

# %% [markdown]
# **Время, проведенное на сайте**
#
# | **Аспект**                  | **Описание**                                                                                                                                                               |
# |---------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Распределение времени**   |  Распределение времени, проведенного на сайте, имеет унимодальную форму, близкую к нормальному, с пиком в районе 13-16 единиц времени. Ящик с усами также показывает медиану около 13. |
# | **Сводная таблица**        |  Суммарное время, проведенное на сайте, за "текущий_месяц" составляет 17166, а за "предыдущий_месяц" - 17508.                                                              |
# | **Суммарное время по периодам** |  Суммарное время, проведенное на сайте, демонстрирует небольшое снижение от "предыдущий_месяц" до "текущий_месяц". Разница между периодами минимальна.                                   |

# %%
activities = market_file['покупательская_активность'].unique()
for activity in activities:
    print(f"Статистика для группы: {activity}")
    subset = market_file[market_file['покупательская_активность'] == activity]
    display(pd.DataFrame(subset['страниц_за_визит'].describe()).T)
    print("-" * 50)
num_col(df=market_file, x='страниц_за_визит', hue='покупательская_активность',
           xlabel='Кол-во страниц', ylabel='Количество', legend_title='Активность',
           title='Распределение количества страниц, которые просмотрел покупатель за один визит', figsize=(10,5), palette="viridis")
# Out:
# Статистика для группы: Снизилась
#                   count      mean       std  min  25%  50%  75%   max
# страниц_за_визит  498.0  5.568273  3.454265  1.0  3.0  5.0  7.0  18.0
# --------------------------------------------------
# Статистика для группы: Прежний уровень
#                   count      mean       std  min  25%   50%   75%   max
# страниц_за_визит  802.0  9.796758  3.376846  3.0  7.0  10.0  12.0  20.0
# --------------------------------------------------

# %% [markdown]
# **Количество страниц за один визит**
#
# | **Аспект**               | **Описание**                                                                                                                                                                     |
# |--------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Симметрия**             |  Распределение количества просмотренных страниц за визит более симметрично у пользователей с прежним уровнем покупательской активности.                                               |
# | **Наиболее частые значения** |  У пользователей с прежним уровнем покупательской активности наиболее часто просматривается 8-10 страниц за визит, в то время как у пользователей со сниженным уровнем – 3-4 страницы.    |
# | **Минимальные значения**    |  Минимальное количество просмотренных страниц за визит у пользователей со сниженным уровнем составляет 1, а у пользователей с прежним уровнем – 3.                                  |
# | **Максимальные значения**  |  Максимальное количество просмотренных страниц за визит у пользователей со сниженным уровнем составляет 18, а у пользователей с прежним уровнем – 20.                                |
# | **Медианы**               |  Пользователи с прежним уровнем покупательской активности просматривают в среднем в 2 раза больше страниц за визит (медиана — 10), чем пользователи со сниженным уровнем (медиана — 5). |

# %%
num_col(df=market_file, x='ошибка_сервиса', hue='покупательская_активность',
           xlabel='Число сбоев во время посещения сайта', ylabel='Количество', legend_title='Активность',
           title='Распределение сбоев', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Число сбоев во время посещения сайта**
#
# | **Аспект**                  | **Описание**                                                                                                                                                                       |
# |-----------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Симметрия**               |  Распределение количества сбоев сайта более симметрично у пользователей с прежним уровнем покупательской активности.                                                                |
# | **Наиболее частые значения** |  У пользователей с прежним уровнем покупательской активности наиболее часто встречается 4 сбоя, в то время как у пользователей со сниженным уровнем – 3 сбоя.                         |
# | **Диапазон значений**        |  Минимальное количество сбоев у пользователей со сниженным уровнем составляет 1, а у пользователей с прежним уровнем – 0. Максимальное количество сбоев для обеих групп пользователей одинаково и равно 9. |
# | **Медианы**                 |  Пользователи обеих групп имеют одинаковое медианное количество сбоев сайта – 4.                                                                                                  |

# %% [markdown]
# **Вывод по поведению на сайте**
#
# **Общие наблюдения:**
#
# *   Анализ поведения на сайте разделен на две группы: "снизившие активность" и "сохранившие прежний уровень активности".
# *   Рассматривались три основных параметра: время, проведенное на сайте, количество просмотренных страниц за визит и число сбоев во время посещения сайта.
#
# **Время, проведенное на сайте:**
#
# *   **Общая картина:** Распределение времени на сайте близко к нормальному, с пиком в районе 13-16 единиц времени.
# *   **Сравнение периодов:** Суммарное время на сайте немного снизилось с предыдущего месяца на текущий, но разница минимальна.
# *   **Вывод:** Общая тенденция по времени, проведенному на сайте, осталась стабильной.
#
# **Количество страниц за один визит:**
#
# *   **Наиболее частые значения:**
#     *   Прежний уровень: 8-10 страниц за визит.
#     *   Сниженный уровень: 3-4 страницы за визит.
# *   **Медианы:** Пользователи с прежним уровнем активности просматривают в среднем в 2 раза больше страниц за визит (медиана - 10), чем пользователи со сниженным уровнем (медиана - 5).
# *   **Вывод:** Пользователи с прежним уровнем активности демонстрируют более активное взаимодействие с сайтом, просматривая существенно больше страниц за визит.
#
# **Число сбоев во время посещения сайта:**
#
# *   **Наиболее частые значения:**
#     *   Прежний уровень: 4 сбоя.
#     *   Сниженный уровень: 3 сбоя.
# *   **Медианы:** Обе группы имеют одинаковое медианное количество сбоев сайта - 4.
# *   **Вывод:** Количество сбоев во время посещения сайта в целом одинаково для обеих групп, хотя есть небольшие различия в наиболее частых значениях.
#
# **Общий вывод:**
#
# Пользователи с прежним уровнем покупательской активности демонстрируют более активное взаимодействие с сайтом, просматривая значительно больше страниц за визит, чем пользователи со сниженным уровнем. При этом общее время, проведенное на сайте, и число сбоев во время посещения сайта не имеют существенных различий между группами. Это указывает на то, что пользователи с прежним уровнем активности более целенаправленно изучают сайт, что может быть связано с их более обдуманными покупками.

# %% [markdown]
# ### Финансовое поведение

# %%
num_col(df=market_money, x='выручка',
           xlabel='Сумма выручки', ylabel='Количество', legend_title='Активность',
           title='Распределение выручки', figsize=(10,5), palette="viridis")

# %%
print(market_money.query('выручка > 100000'))
market_money.query('выручка < 1')
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2
#         id               период  выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0

# %% [markdown]
# Выбросы, от которых мы избавимся.
# Записи с 0 выручкой удаляем, потому что мы хотим в дальнейшем использовать только тех пользователей, у которых есть активность за три месяца, а такие пустые записи явно не соответствуют требованиям.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Действительно явный выброс.
# Можно удалить, а можно и заполнить, например значением предыдущего месяца.</font>

# %%
market_money = market_money[(market_money['выручка'] >= 1) & (market_money['выручка'] <= 100000)]
num_col(df=market_money, x='выручка',
           xlabel='Сумма выручки', ylabel='Количество', legend_title='Активность',
           title='Распределение выручки', figsize=(10,5), palette="viridis")

# %%
pivot_table = market_money.groupby('период')['выручка'].agg(['sum'])
pivot_table = pivot_table.round(0)
pivot_table = pivot_table.sort_values(by='sum', ascending=True)
print("Сводная таблица:")
print(pivot_table)

plt.figure(figsize=(8, 4))
sns.barplot(x=pivot_table.index, y=pivot_table['sum'], palette="viridis")
plt.xlabel('Период')
plt.ylabel('Сумма выручки')
plt.title('Суммарная выручка по периодам')
plt.grid(True)
plt.show()
# Out:
# Сводная таблица:
#                            sum
# период
# препредыдущий_месяц  6272769.0
# предыдущий_месяц     6417996.0
# текущий_месяц        6802587.0

# %% [markdown]
# **Выручка**
#
# | **Аспект**                     | **Описание**                                                                                                                                                                                           |
# |------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Распределение выручки**     |  Распределение выручки имеет унимодальную форму с пиком в районе 4000-6000, наблюдается заметный "хвост" в сторону более высоких значений. Выбросы практически отсутствуют.                                |
# | **Сводная таблица**           |  Суммарная выручка за "текущий_месяц" наибольшая (6 802 587), за "предыдущий_месяц" - 6 417 996, а за "препредыдущий_месяц" - 6 272 769.                                                            |
# | **Суммарная выручка по периодам** |  Суммарная выручка демонстрирует рост от "предыдущий_месяц" до "текущий_месяц". При этом "препредыдущий_месяц" показывает самые низкие значения. Разница между периодами не столь значительна, но восходящая тенденция все же имеется. |
# | **Количество строк**           |  Изначально было в market_money 3900 строк, после фильтрации осталось 3893 строк, удалено 7 строк с выручкой 0 и более 100.000.                                                                      |

# %%
num_col(df=money, x='прибыль',
           xlabel='Прибыль', ylabel='Количество', legend_title='Активность',
           title='Распределение прибыли', figsize=(10,5), palette="viridis")

# %% [markdown]
# **Распределение прибыли**
#
# | **Аспект**            | **Описание**                                                                                                                                    |
# |-----------------------|-----------------------------------------------------------------------------------------------------------------------------------------------|
# | **Распределение прибыли** |  График гистограммы показывает, что распределение прибыли является нормальным с пиком около 4.                                                   |
# | **Медиана**           |  На графике ящика с усами видно, что медиана распределения находится около 4, что соответствует пику гистограммы.                                   |
# | **Выбросы**            |  Также на ящике с усами видно, что имеются выбросы (отдельные точки за пределами усов) - несколько данных о прибыли превышают 7.                   |
# | **Межквартильный размах**|  Межквартильный размах относительно невелик, что указывает на небольшое различие в прибыли между центральной частью данных.                 |

# %% [markdown]
# **Вывод по финансовым данным**
#
# **Общие наблюдения:**
#
# *   Проведена очистка данных: удалены 7 строк с нулевой выручкой, так как для анализа требуются пользователи с активностью за три месяца.
# *   Рассмотрены два основных параметра: выручка и прибыль.
#
# **Выручка:**
#
# *   **Суммарные значения:** Суммарная выручка растет от "препредыдущий_месяц" (6,272,769) к "текущий_месяц" (6,802,587), демонстрируя восходящую тенденцию.
# *   **Динамика:** Выручка увеличивается с каждым месяцем, что свидетельствует о положительной динамике.
# *   **Вывод:** Наблюдается стабильный рост выручки от месяца к месяцу.
#
# **Прибыль:**
#
# *   **Распределение:** Распределение прибыли нормальное, с пиком около 4.
# *   **Межквартильный размах:** Межквартильный размах относительно невелик, указывая на небольшую вариативность прибыли в центральной части данных.
# *   **Вывод:** Распределение прибыли близко к нормальному, с небольшими отклонениями в виде выбросов.
#
# **Общий вывод:**
#
# Финансовые данные показывают положительную динамику: выручка стабильно растет от месяца к месяцу. Распределение прибыли нормальное, с небольшими отклонениями, что свидетельствует о стабильных финансовых показателях. Проведена небольшая предобработка данных, удалив записи с нулевой выручкой.

# %% [markdown]
# ### Отбор клиентов с активностью покупок не менее 3 месяцев

# %% [markdown]
# Для дальнейшего анализа необходимо отобрать пользователей с устойчивой активностью, совершавших покупки в течение последних трех месяцев.
#
# Нам нужны записи из market_money, где для одного клиента есть данные за периоды ‘препредыдущий_месяц’, ‘предыдущий_месяц’ и ‘текущий_месяц’.

# %%
not_active_clients = [215348, 215357, 215359, 215380]

# %% [markdown]
# Удаляем 3 ID из всех Датафреймов

# %%
def filter_active_clients(df, not_active_clients):
    condition = ~df['id'].isin(not_active_clients)
    return df[condition]

market_file = filter_active_clients(market_file, not_active_clients)
market_money = filter_active_clients(market_money, not_active_clients)
market_time = filter_active_clients(market_time, not_active_clients)
money = filter_active_clients(money, not_active_clients)

# %% [markdown]
# **Вывод по отбору клиентов**
#
# Во всех датафреймах были удалены пользователи (id: 215348, 215357, 215359), которые за последние 3 месяца хотя бы в одном месяце не принесли выручку.

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#     <h3><span style="color:#8B008B">Вывод по исследовательскому анализу данных</span></h3>
#     <br>
#     <span style="font-size: 1em;">
#         Исследование выявило существенные различия в поведении пользователей с разной активностью.
#         Пользователи со сниженной активностью, несмотря на более долгую регистрацию и склонность к акциям,
#         менее вовлечены с сайтом, но возможно более целенаправленны в покупках.
#         Активные пользователи, напротив, более вовлечены, меньше бросают корзины, но их акционные покупки менее выражены.
#         "Премиум" пользователи более склонны к снижению активности, чем "стандарт".
#         В предпочтениях по категориям есть различия: снижение активности связано со "спонтанными", сохранение - с "обдуманными".
#         При этом наблюдается общий рост выручки и стабильное время на сайте.
#     </span>
#     <br>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Ключевые моменты:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Различия в активности:</span>
#             <span style="font-size: 1em;">
#                Снижение активности - дольше зарегестрированы, больше покупок по акциям, но меньшая вовлеченность.
#                Прежняя активность - большая вовлеченность, меньше брошенных корзин, но меньше доля акционных покупок.
#             </span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">"Премиум" нестабильность:</span>
#             <span style="font-size: 1em;">"Премиум" пользователи более склонны к снижению активности.</span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Разные категории:</span>
#            <span style="font-size: 1em;">Снижение активности связано с более "спонтанными" категориями, сохранение - с более "обдуманными".</span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Рост выручки:</span>
#             <span style="font-size: 1em;">Наблюдается общий рост выручки и стабильное время на сайте.</span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Необходимость персонализации:</span>
#             <span style="font-size: 1em;">Требуется сегментация, персонализация маркетинга, удержание "премиум" и поощрение "стандарт" пользователей.</span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# Для продолжения анализа нам нужно объединить имеющиеся таблицы.
# Перед этим, в таблицу с данными о минутах мы добавим столбцы ‘минуты_предыдущий_месяц’ и ‘минуты_текущий_месяц’. В таблицу с выручкой - столбцы ‘выручка_препредыдущий_месяц’,‘выручка_предыдущий_месяц’ и ‘выручка_текущий_месяц’.

# %%
time_table = market_time.pivot_table(index=['id'],columns=['период'],values=['минут'])
time_table.columns = ['минуты_предыдущий_месяц','минуты_текущий_месяц']
time_table = time_table.reset_index()
time_table.head()
# Out:
#        id  минуты_предыдущий_месяц  минуты_текущий_месяц
# 0  215349                       12                    10
# 1  215350                        8                    13
# 2  215351                       11                    13
# 3  215352                        8                    11
# 4  215353                       10                    10

# %%
money_table = market_money.pivot_table(index=['id'],columns=['период'],values=['выручка'])
money_table.columns = ['выручка_предыдущий_месяц','выручка_препредыдущий_месяц','выручка_текущий_месяц']
money_table = money_table.reset_index()
money_table.head()
# Out:
#        id  выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 0  215349                    5216.0                       4472.0
# 1  215350                    5457.5                       4826.0
# 2  215351                    6158.0                       4793.0
# 3  215352                    5807.5                       4594.0
# 4  215353                    4738.5                       5124.0
#
#    выручка_текущий_месяц
# 0                 4971.6
# 1                 5058.4
# 2                 6610.4
# 3                 5872.5
# 4                 5388.5

# %%
market_file.reset_index(inplace=True,drop=True)
time_table.reset_index(inplace=True,drop=True)
money_table.reset_index(inplace=True,drop=True)
data = market_file.merge(time_table, on='id',how='inner').merge(money_table, on='id', how='inner')
display(data.head())
data.info()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.выручка_текущий_месяц.max()
# Out:
# 7799.4

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#     <h3><span style="color:#8B008B">Вывод по подготовке и объединению данных</span></h3>
#     <br>
#     <span style="font-size: 1em;">
#        Данные успешно преобразованы и объединены в единый DataFrame <code>data</code>, готовый для дальнейшего анализа.
#     </span>
#     <br>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Основные этапы:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Создание таблиц <code>time_table</code> и <code>money_table</code>:</span>
#             <span style="font-size: 1em;">
#                 Сводные таблицы созданы из <code>market_time</code> и <code>market_money</code>, содержащие данные о минутах и выручке за разные периоды.
#                 Столбцы переименованы в <code>минуты_предыдущий_месяц</code>, <code>минуты_текущий_месяц</code> и <code>выручка_предыдущий_месяц</code>, <code>выручка_препредыдущий_месяц</code>, <code>выручка_текущий_месяц</code>.
#             </span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Сброс индексов:</span>
#             <span style="font-size: 1em;">Индексы сброшены в <code>market_file</code>, <code>time_table</code> и <code>money_table</code> для подготовки к объединению.</span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Объединение таблиц:</span>
#             <span style="font-size: 1em;">
#                 Таблицы объединены в <code>data</code> с помощью <code>merge</code> по столбцу <code>id</code> (inner join).
#                 В результирующем DataFrame <code>data</code> остались только записи, присутствующие во всех трех таблицах.
#             </span>
#          </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;"><span style="font-weight:bold">Результат:</span>
#             <span style="font-size: 1em;">DataFrame <code>data</code> содержит 1297 записей и 18 столбцов.
#             Каждая строка представляет пользователя с данными о его поведении, времени на сайте и выручке.
#             </span>
#         </li>
#     </ul>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Общий итог:</span>
#     <br>
#     <span style="font-size: 1em;">
#         DataFrame <code>data</code> теперь содержит все необходимые данные в структурированном формате и готов к дальнейшему анализу.
#         Процесс объединения проведен корректно, что обеспечивает целостность и готовность данных к следующим этапам.
#     </span>
# </div>

# %% [markdown]
# ## Корреляционный анализ

# %%
id_column = None
if 'id' in data.columns:
    id_column = data['id'].copy()
    data = data.drop('id', axis=1)

phik_matrix = data.phik_matrix()

if id_column is not None:
    data['id'] = id_column

if "покупательская_активность" in phik_matrix.columns:
    correlation_column = phik_matrix[["покупательская_активность"]]
    sorted_correlation = correlation_column.sort_values(by="покупательская_активность", ascending=False)
    plt.figure(figsize=(10, 8))
    sns.heatmap(sorted_correlation, annot=True, fmt=".2f", cmap='coolwarm')
    plt.title("Корреляции столбца 'покупательская_активность' (по убыванию)")
    plt.show()
else:
    print("Столбец 'покупательская_активность' отсутствует в матрице корреляции.")
# Out:
# interval columns not set, guessing: ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'минуты_предыдущий_месяц', 'минуты_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц']

# %% [markdown]
# **Выводы на основании матрицы корреляции:**
#
# **Сильная положительная корреляция (0.5 и выше):**
#
# - **Количество страниц за визит (0.75)**: Чем больше страниц посещает пользователь за один визит, тем выше его покупательская активность.
# - **Минуты предыдущий месяц (0.69) и минуты текущий месяц (0.58)**: Время, проведенное на сайте в предыдущем и текущем месяцах, также сильно коррелирует с покупательской активностью.
# - **Маркетинговая активность за 6 месяцев (0.55)**: Похоже, что маркетинговые усилия, предпринятые за последние полгода, положительно влияют на покупательскую активность.
# - **Средний просмотр категорий за визит (0.54)**: Пользователи, просматривающие большее количество категорий за визит, более склонны к активным покупкам.
# - **Акционные покупки (0.51)**: Наличие акционных покупок тесно связано с общей покупательской активностью. Вероятно, скидки и акции стимулируют покупателей.
# - **Неоплаченные продукты (0.50)**: Удивительно, но наличие неоплаченных продуктов также коррелирует с покупательской активностью. Возможно, это связано с тем, что покупатели добавляют товары в корзину, но не всегда завершают покупку, тем не менее остаются активными.
# - **Выручка за предпредыдущий месяц (0.50)**: Доход от покупок за прошлый месяц также сильно коррелирует с общей активностью покупателей.
#
# **Средняя положительная корреляция (0.2 - 0.5):**
#
# - **Популярная категория (0.30)**: Популярность категории товаров имеет среднюю корреляцию с покупательской активностью. Это может говорить о том, что покупатели часто совершают покупки в популярных категориях.
# - **Выручка за предыдущий месяц (0.23)**: Корреляция выручки за предыдущий месяц с покупательской активностью менее сильная, чем выручка за предпредыдущий. Это может быть связано с тем, что более старая история покупок лучше влияет на предсказания активности покупателя.
# - **Ошибка сервиса (0.22)**: Корреляция наличия ошибки сервиса с покупательской активностью достаточно неожиданная, но положительная. Возможно, это связано с тем, что покупатели, столкнувшиеся с ошибкой, всё равно могут совершать покупки.
#
# **Слабая положительная корреляция (0 - 0.2):**
#
# - **Тип сервиса (0.13)**: Тип сервиса, которым пользуются покупатели, слабо коррелирует с их общей активностью.
# - **Длительность (0.10)**: Время, проведенное на сайте, оказывает небольшое влияние на покупательскую активность.
#
# **Нулевая корреляция (0.00):**
#
# - **Маркетинговая активность за текущий месяц**: На удивление, маркетинговая активность в текущем месяце не коррелирует с покупательской активностью. Это может быть связано с тем, что текущие маркетинговые кампании еще не успели повлиять на покупателей, или что их влияние невелико.
# - **Разрешить сообщать**: Разрешение пользователя на получение сообщений не коррелирует с его покупательской активностью.
# - **Выручка текущего месяца**: В текущем месяце нет явной связи между выручкой и покупательской активностью. Это может быть связано с тем, что покупки в текущем месяце еще не полностью отражены в данных, или что влияние выручки больше в прошлых периодах.
#
# **Общие выводы:**
#
# - Наиболее сильное влияние на покупательскую активность оказывают поведение пользователей на сайте (количество просмотренных страниц, время, проведенное на сайте), прошлые покупки (количество акционных покупок, выручка за прошлые периоды).
# - Маркетинговая активность и не все показатели финансового характера (выручка текущего месяца) имеют не такое сильное влияние на покупательскую активность, и их эффективность, возможно, требует пересмотра.
# - Понимание того, какие факторы коррелируют с покупательской активностью, позволит компании более эффективно таргетировать свои маркетинговые усилия и персонализировать пользовательский опыт для увеличения продаж.

# %%
id_column = None
if 'id' in data.columns:
    id_column = data['id'].copy()
    data = data.drop('id', axis=1)

phik_matrix = data.phik_matrix()

if id_column is not None:
    data['id'] = id_column

plt.figure(figsize=(15, 10))
sns.heatmap(phik_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Матрица корреляции Phi_K")
plt.show()
# Out:
# interval columns not set, guessing: ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'минуты_предыдущий_месяц', 'минуты_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц']

# %% [markdown]
# **Вывод на основе матрицы корреляции:**
#
# **Сильная корреляция с покупательской активностью:**
# - **Количество страниц за визит**: Чем больше страниц посещает пользователь за один визит, тем выше его покупательская активность.
# - **Время, проведенное на сайте**: Минуты за предыдущий и текущий месяцы также показывают сильную положительную корреляцию с покупательской активностью.
# - **Маркетинговая активность за 6 месяцев**: Долгосрочные маркетинговые усилия оказывают значительное влияние на вовлеченность пользователей.
# - **Средний просмотр категорий за визит**: Пользователи, просматривающие больше категорий, более склонны к совершению покупок.
# - **Акционные покупки**: Наличие акционных предложений способствует повышению покупательской активности.
# - **Выручка за предпредыдущий месяц**: Этот показатель также сильно коррелирует с общей активностью покупателей.
#
# Эти факторы являются ключевыми индикаторами вовлеченности и готовности пользователя совершить покупку.
#
# **Средняя корреляция с покупательской активностью:**
# - **Популярная категория**: Имеет среднюю корреляцию с покупательской активностью, указывая на то, что покупатели чаще совершают покупки в популярных категориях.
# - **Выручка за предыдущий месяц**: Также демонстрирует среднюю корреляцию с покупательской активностью.
#
# **Слабая корреляция или ее отсутствие:**
# - **Тип сервиса**: Слабо коррелирует с общей активностью покупателей.
# - **Длительность**: Время, проведенное на сайте, оказывает небольшое влияние на покупательскую активность.
# - **Маркетинговая активность за текущий месяц**: Не коррелирует с покупательской активностью, возможно, из-за недостаточной эффективности текущих кампаний.
# - **Разрешение на сообщения**: Не влияет на покупательскую активность.
# - **Выручка текущего месяца**: Нет явной связи с покупательской активностью, что может быть связано с незавершенными покупками.
#
# Эти факторы могут указывать на то, что их влияние на покупательское поведение не так очевидно в текущих данных.
#
# **Неожиданная корреляция:**
# - **Наличие неоплаченных продуктов**: Коррелирует с покупательской активностью, что требует более детального анализа.
# - **Ошибки сервиса**: Также показывают положительную корреляцию с покупательской активностью, что может быть неожиданным.
#
# **Выводы о мультиколлинеарности:**
# - **Минуты предыдущий месяц и минуты текущий месяц (0.41)**: Эти переменные, связанные со временем на сайте, ожидаемо сильно коррелируют между собой.
# - **Выручка предыдущий месяц и выручка предпредыдущий месяц (0.36)**: Логично, что выручка за разные прошлые периоды имеет сильную корреляцию.
#
# **Рекомендации:**
# - При построении моделей машинного обучения стоит учитывать высокую корреляцию между минутами предыдущего и текущего месяца, а также выручками за прошлые месяцы. Возможно, следует удалить одну из этих переменных или использовать регуляризацию для снижения мультиколлинеарности.

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#     <h3><span style="color:#8B008B">Вывод по корреляционному анализу</span></h3>
#     <br>
#     <span style="font-size: 1em;">
#         <b>Общие выводы:</b>
#         <br>
#         Наиболее сильное влияние на покупательскую активность оказывают поведение пользователей на сайте и прошлые покупки.
#         <br>
#         Маркетинговая активность и некоторые финансовые показатели имеют менее сильное влияние на активность.
#         <br>
#         Понимание факторов, коррелирующих с покупательской активностью, поможет более эффективно таргетировать маркетинговые усилия.
#     </span>
#     <br>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Выводы о мультиколлинеарности:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;">
#              <span style="font-size: 1em;">
#             Минуты предыдущий месяц и минуты текущий месяц (0.48) коррелируют между собой.
#             </span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;">
#             <span style="font-size: 1em;">
#             Выручка предыдущий месяц и выручка предпредыдущий месяц (0.36) также имеют сильную корреляцию.
#             </span>
#         </li>
#     </ul>
#     <br>
#       <span style="font-size: 1.2em; font-weight: bold;">Рекомендации:</span>
#         <br>
#      <span style="font-size: 1em;">
#           При построении моделей машинного обучения стоит учитывать высокую корреляцию между переменными времени и выручки за прошлые месяцы.
#      </span>
# </div>

# %% [markdown]
# ## Пайплайны

# %% [markdown]
# Подготовим данные.
# Закодируем целевой признак в значение 0 и 1.
# Превратим колонку акционные_покупки в категоральный признак.

# %%
data['акционные_покупки_категория'] = data['акционные_покупки'].apply( lambda x: 'Часто покупает по акции' if x>= 0.6 else 'Редко покупает по акции' )
data = data.drop(['акционные_покупки'], axis=1)
data['покупательская_активность'] = data['покупательская_активность'].replace({'Снизилась': 1, 'Прежний уровень': 0})
data.head(5)
# Out:
#    покупательская_активность тип_сервиса разрешить_сообщать  \
# 0                          1     премиум                 да
# 1                          1    стандарт                нет
# 2                          1    стандарт                 да
# 3                          1    стандарт                нет
# 4                          1    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                 4.4                     4           819
# 1                 4.9                     3           539
# 2                 3.2                     5           896
# 3                 5.1                     3          1064
# 4                 3.3                     4           762
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    4
# 1    Домашний текстиль                                    5
# 2     Товары для детей                                    5
# ...

# %%
X = data.drop(['покупательская_активность'], axis=1)
y = data['покупательская_активность']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify = data['покупательская_активность']
)
X_train_model = X_train.drop('id',axis=1)
X_test_model = X_test.drop('id',axis=1)

# %%
ohe_columns = ['разрешить_сообщать', 'популярная_категория', 'тип_сервиса']
ord_columns = ['акционные_покупки_категория']
num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 
               'длительность', 'средний_просмотр_категорий_за_визит',
               'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 
               'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 
               'минуты_предыдущий_месяц', 'минуты_текущий_месяц']

# %%
categorical_transformer = ColumnTransformer(
    [
        ('onehot', OneHotEncoder(handle_unknown='ignore'), ohe_columns),
        ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ord_columns),
    ], remainder='passthrough'
)

data_preprocessor = ColumnTransformer(
    [
        ('categorical', categorical_transformer, ohe_columns + ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)


pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('model', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

param_distributions = [
    {
        'model': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'model__max_depth': range(2,10),
        'model__max_features': range(2,10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),  'passthrough']  
    },  
    {
        'model': [KNeighborsClassifier()],        
        'model__n_neighbors': range(1,6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),'passthrough']    
    },
    {
        'model': [LogisticRegression(solver='liblinear', penalty='l1', random_state=RANDOM_STATE)],
        'model__C': range(1,5),        
        'preprocessor__num': [StandardScaler(), MinMaxScaler(),'passthrough']  
    },

    {
        'model': [SVC(probability=True, random_state=RANDOM_STATE)],
        'models__degree': range(2, 3),
        'preprocessor__num': [StandardScaler(), 'passthrough']
}
]

randomized_search = RandomizedSearchCV(
    pipe_final,
    param_distributions,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    n_iter=10,
    random_state=RANDOM_STATE
)

randomized_search.fit(X_train_model, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

y_test_pred = randomized_search.predict(X_test_model)
roc_auc = roc_auc_score(y_test, y_test_pred)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc:.4f}')

probabilities = randomized_search.predict_proba(X_test_model)
probabilities_one = probabilities[:, 1]
roc_auc = roc_auc_score(y_test, probabilities_one)
print(f'Метрика ROC-AUC для класса 1 на тестовой выборке: {roc_auc:.4f}')

best_model = randomized_search.best_estimator_
num_transformer = best_model.named_steps['preprocessor'].named_transformers_['num']

if isinstance(num_transformer, StandardScaler):
    print("Лучший скейлер: StandardScaler")
elif isinstance(num_transformer, MinMaxScaler):
    print("Лучший скейлер: MinMaxScaler")
else:
    print("Лучший скейлер: passthrough (нет скейлера)")
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categorical',
#                                                   ColumnTransformer(remainder='passthrough',
#                                                                     transformers=[('onehot',
#                                                                                    OneHotEncoder(handle_unknown='ignore'),
#                                                                                    ['разрешить_сообщать',
#                                                                                     'популярная_категория',
#                                                                                     'тип_сервиса']),
#                                                                                   ('ordinal',
# ...

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#     <h3><span style="color:#8B008B">Вывод по моделям и метрикам</span></h3>
#     <span style="font-size: 1em;">
#         <br>
#         В ходе анализа были протестированы различные модели, и наилучшие результаты показала модель SVC, что подтверждает её эффективность для данной задачи.
#     </span>
#     <br>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Основные этапы:</span>
#     <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#         <li style="margin-bottom: 5px; line-height: 1.3;">
#             <span style="font-weight:bold">Используемые модели:</span>
#             <br>
#             <span style="font-size: 1em;">
#                <code>DecisionTreeClassifier</code>,<br>
#                 <code>KNeighborsClassifier</code>,<br>
#                 <code>LogisticRegression</code>,<br>
#                 <code>SVC</code>
#             </span>
#         </li>
#         <li style="margin-bottom: 5px; line-height: 1.3;">
#             <span style="font-weight:bold">Лучшая модель:</span>
#              <br>
#             <span style="font-size: 1em;">
#                 Модель: <code>LogisticRegression </code><br>
#                 Гиперпараметры: <code>C=1, penalty='l1', solver='liblinear'</code> <br>
#                 Метрика на тренировочной выборке: <code>0.8938 </code><br>
#                Метрика ROC-AUC на тестовой выборке: <code>0.8825</code>
#             </span>
#         </li>
#           <li style="margin-bottom: 5px; line-height: 1.3;">
#             <span style="font-weight:bold">Выбор метрики:</span>
#             <br>
#               <span style="font-size: 1em;">
#                 Подходит для задач бинарной классификации: ROC-AUC особенно полезна в случаях, когда нужно оценить качество классификатора в задачах бинарной классификации (когда есть два класса). <br>
#                 Хорошо интерпретируется: Значение ROC-AUC лежит в диапазоне от 0 до 1. Значение 0.5 означает, что модель делает случайные предсказания, а значение 1 говорит об идеальной классификации.<br>
#                 Учет дисбаланса классов: ROC-AUC менее чувствительна к дисбалансу классов, чем метрика точности (accuracy), что является важным фактором в контексте данной задачи.
#               </span>
#         </li>
#     </ul>
#     <br>
#     <span style="font-size: 1.2em; font-weight: bold;">Общий итог:</span>
#      <br>
#     <span style="font-size: 1em;">
#          Модель LogisticRegression, использующая отсутствие масштабирования (passthrough), продемонстрировала наилучшие результаты, что подтверждает её эффективность для данной задачи. Выбор метрики способствовал более точной оценке производительности модели и её способности к обобщению на тестовых данных. Отсутствие необходимости в масштабировании может указывать на особенности данных, которые следует учитывать в дальнейшем анализе.
#     </span>
#     </span>
# </div>

# %% [markdown]
# ## Анализ важности признаков

# %%
best_estimator = randomized_search.best_estimator_
preprocessor = best_estimator.named_steps['preprocessor']
X_train_2 = preprocessor.fit_transform(X_train_model)
explainer = shap.Explainer(best_estimator.named_steps['model'], X_train_2)
X_test_2 = preprocessor.transform(X_test)
feature_names = preprocessor.get_feature_names_out()
X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)
 
shap_values = explainer(X_test_2)
 
shap_vals = shap_values.values
feature_names = list(X_test_2.columns)

feature_order = np.argsort(np.abs(shap_vals).mean(axis=0))[::-1]
feature_order = feature_order[:30]

y_pos = np.arange(len(feature_order))
shap_means = np.abs(shap_vals).mean(axis=0)
sorted_shap_values = shap_means[feature_order]
sorted_feature_names = [feature_names[i] for i in feature_order]

plt.figure(figsize=(12, 8))
bars = plt.barh(y_pos, sorted_shap_values, align='center', color="#66b3ff")
plt.yticks(y_pos, sorted_feature_names, fontsize=12)
plt.xlabel("Mean Absolute SHAP Value", fontsize=12)
plt.title("Feature Importance (Mean Absolute SHAP Values)", fontsize=14)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

for bar, shap_value in zip(bars, sorted_shap_values):
    width = bar.get_width()
    plt.text(width + 0.01,
             bar.get_y() + bar.get_height()/2,
             f'{shap_value:.2f}',
             ha='left',
             va='center',
             fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Собиралась строить график по коду ниже, **но выводится ошибка**, видимо связанная с версиями библиотек.
# Я поустанавливала версии, 1 раз удалось загрузить график, но потом все сломалось.
# В тех. поддержу обращалась дважды, три дня мне не могли сделать.
# В итоге пошла обходным графиков.
# Ниже прилагаю код

# %%
best_estimator = randomized_search.best_estimator_
preprocessor = best_estimator.named_steps['preprocessor']
X_train_2 = preprocessor.fit_transform(X_train_model)
explainer = shap.Explainer(best_estimator.named_steps['model'], X_train_2)
X_test_2 = preprocessor.transform(X_test)
feature_names = preprocessor.get_feature_names_out()
X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)
shap_values = explainer(X_test_2)
shap.plots.bar(shap_values, max_display=30, show=False)
plt.show()

# %%
shap.plots.beeswarm(shap_values, max_display=15)

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#
# ### <span style="color:#8B008B">Вывод по анализу важности признаков</span>
#
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">num_страниц_за_визит: (Наиболее важный признак):</span> Высокие значения этого признака сильно связаны с пониженной вероятностью оттока. Пользователи, активно просматривающие страницы сайта, более лояльны.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">num_средний_просмотр_категорий_за_визит:</span> Как и ожидалось, более высокий средний просмотр категорий за визит коррелирует с меньшей вероятностью оттока. Активное изучение ассортимента указывает на вовлеченность.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">num_минуты_предыдущий_месяц & num_минуты_текущий_месяц:</span> Время, проведенное на сайте в течение месяца, также обратно пропорционально оттоку. Больше времени = больше лояльности.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">num_неоплаченные_продукты_штук_квартал:</span> Чем больше неоплаченных продуктов, тем выше вероятность оттока. Возможно стоит улучшить систему напоминания оплаты.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">num_маркет_актив_6_мес:</span> Более высокая активность в маркете за последние 6 месяцев также связана с пониженной вероятностью оттока.
#     </li>
# </ul>
#
# <br>
#
#  <span style="font-size: 1.2em; font-weight: bold;">Бизнес-решения:</span>
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: disc;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Предложения для удержания:</b> Клиентам, приобретающим акционные товары определенных категорий (categorical_ordinal_акционные_покупки_категория), предлагать более выгодные условия, программу лояльности или персонализированные рекомендации, чтобы повысить их лояльность.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Поощрение просмотра категорий:</b> Стимулировать пользователей чаще просматривать различные категории товаров, например, с помощью email-рассылок или push-уведомлений с подборками товаров.
#     </li>
# </ul>
#
# <br>
#
#  <span style="font-size: 1.2em; font-weight: bold;">Анализ клиентского опыта:</span>
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: disc;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Акционные категории:</b> Уделить внимание акционным категориям, связанным с оттоком. Возможно, стоит пересмотреть условия акций, качество товаров в этих категориях или маркетинговую стратегию.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Вовлечение в категории:</b> Изучить, почему у пользователей, покупающих мелкую бытовую технику, наблюдается более высокая лояльность. Попытаться перенести этот опыт на другие категории.
#     </li>
# </ul>
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Разделим вероятность снижения активности пользователей на 3 категории:
# 1. Низкая вероятность снижения активности (от 0 до 0.3)
# 2. Пользователи в зоне риска снижения активности (от 0.3 до 0.7)
# 3. Высокая степерь вероятности снизить активность (от 0.1 до 1)

# %%
X_test['вероятность'] = probabilities[:, 1]
def categorize_probability(probability):
    if 0 <= probability <= 0.3:
        return 'Низкая вероятность'
    elif 0.3 < probability <= 0.7:
        return 'Зона риска'
    elif 0.7 < probability <= 1:
        return 'Высокая вероятность'
    else:
        return 'Недопустимая вероятность'

X_test['категория_вероятности'] = X_test['вероятность'].apply(categorize_probability)
X_test.head()
# Out:
#     тип_сервиса разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# 809    стандарт                 да                 4.1                     4
# 302     премиум                нет                 1.4                     4
# 955     премиум                 да                 3.3                     4
# 149     премиум                 да                 3.5                     3
# 582    стандарт                нет                 5.5                     4
#
#      длительность                  популярная_категория  \
# 809           606        Техника для красоты и здоровья
# 302           684                      Товары для детей
# 955           488                     Домашний текстиль
# 149          1057                     Домашний текстиль
# 582           147  Мелкая бытовая техника и электроника
#
#      средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 809                                    6                                   1
# ...

# %%
data_segment = X_test.merge(money, on='id', how='left')
data_segment.head()
# Out:
#   тип_сервиса разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# 0    стандарт                 да                 4.1                     4
# 1     премиум                нет                 1.4                     4
# 2     премиум                 да                 3.3                     4
# 3     премиум                 да                 3.5                     3
# 4    стандарт                нет                 5.5                     4
#
#    длительность                  популярная_категория  \
# 0           606        Техника для красоты и здоровья
# 1           684                      Товары для детей
# 2           488                     Домашний текстиль
# 3          1057                     Домашний текстиль
# 4           147  Мелкая бытовая техника и электроника
#
#    средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 0                                    6                                   1
# ...

# %% [markdown]
# **Изучаемым сегментов выберем пользователей, чья прибыль выше медианной и те, кто находятся только в зоне риска и с высокой вероятностью снижения активности.**

# %%
median_profit = data_segment['прибыль'].median()
data_segment = data_segment[
    ((data_segment['категория_вероятности'] == 'Зона риска') | (data_segment['категория_вероятности'] == 'Высокая вероятность'))
    & (data_segment['прибыль'] > median_profit)
]
print("Пользователи с прибылью выше медианной:")
display(data_segment.head())
# Out:
# Пользователи с прибылью выше медианной:
#    тип_сервиса разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# 4     стандарт                нет                 5.5                     4
# 12     премиум                 да                 3.0                     4
# 13    стандарт                 да                 4.9                     5
# 18    стандарт                 да                 3.8                     4
# 19    стандарт                 да                 4.4                     5
#
#     длительность                  популярная_категория  \
# 4            147  Мелкая бытовая техника и электроника
# 12           558                      Товары для детей
# 13           215                     Домашний текстиль
# 18           756                      Товары для детей
# 19           237        Техника для красоты и здоровья
#
#     средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# ...

# %%
category_counts_X_test = X_test['категория_вероятности'].value_counts()
print("Распределение пользователей по категориям вероятности в X_test:\n", category_counts_X_test)
category_counts_data_segment = data_segment['категория_вероятности'].value_counts()
print("\nРаспределение пользователей по категориям вероятности в data_segment:\n", category_counts_data_segment)
# Out:
# Распределение пользователей по категориям вероятности в X_test:
#  Низкая вероятность     184
# Высокая вероятность     90
# Зона риска              50
# Name: категория_вероятности, dtype: int64
#
# Распределение пользователей по категориям вероятности в data_segment:
#  Высокая вероятность    52
# Зона риска             19
# Name: категория_вероятности, dtype: int64

# %%
total_users = len(data_segment)
plt.figure(figsize=(8, 5))
ax = sns.countplot(data=data_segment, x='акционные_покупки_категория', palette='pastel')

plt.title('Распределение количества пользователей по категориям акционных покупок', fontsize=12)
plt.xlabel('Категория акционных покупок', fontsize=10)
plt.ylabel('Количество пользователей', fontsize=10)

plt.xticks(rotation=0, ha='center', fontsize=10)
plt.yticks(fontsize=8)

plt.tight_layout()

for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height / total_users)
    count = int(height)
    label = f'{count}\n({percentage})'
    x = p.get_x() + p.get_width() / 2
    y = height / 2
    ax.text(x, y, label, ha='center', va='center', color='black', fontsize=12)

plt.show()

# %% [markdown]
# **Выводы по сегменту пользователей, склонных к снижению активности (на основе анализа категорий акционных покупок):**
#
# *   **Ключевой фактор:** Снижение активности, вероятно, связано с тем, как часто пользователи совершают покупки по акциям.
#
# *   **Группа риска:** Пользователи, которые "Редко покупают по акции", составляют больший сегмент (68.5%). Вероятно, именно эта группа больше всего подвержена риску снижения активности. Если пользователь редко видит интересные для себя акционные предложения, он может реже посещать сайт и совершать покупки в целом.
#
# *   **Возможные действия:**
#
#     *   **Персонализация акций:** Для пользователей, которые "Редко покупают по акции", важно предлагать более персонализированные акционные предложения, чтобы повысить их вовлеченность.
#
#     *   **Анализ причин редких покупок:** Необходимо понять, почему пользователи редко покупают по акциям. Возможно, акции не соответствуют их интересам, они не знают о проводимых акциях, или у них нет стимула для участия в акциях.

# %%
plt.figure(figsize=(12, 7))

ax = sns.countplot(data=data_segment, x='популярная_категория', palette='viridis',
                   order = data_segment['популярная_категория'].value_counts().index)

plt.title('Распределение пользователей по популярным категориям', fontsize=14)
plt.xlabel('Популярная категория', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()

for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height / total_users)
    count = int(height)
    label = f'{count}\n({percentage})'
    x = p.get_x() + p.get_width() / 2
    y = height / 2
    ax.text(x, y, label, ha='center', va='center', color='white', fontsize=12)
plt.show()

# %% [markdown]
# **Выводы по сегменту пользователей, склонных к снижению активности (на основе анализа популярных категорий):**
#
# Анализ популярных категорий среди пользователей, склонных к снижению активности, выявил следующее:
#
# *   **Основной интерес:** Сегмент пользователей демонстрирует наиболее выраженный интерес к категориям "Товары для детей" (26.0%), "Домашний текстиль" (23.3%) и "Косметика и аксессуары" (23.3%).
#
# *   **Категории с меньшим интересом:** Категории "Мелкая бытовая техника и электроника" (2.7%) и "Техника для красоты и здоровья" (8.2%) пользуются значительно меньшей популярностью среди данной группы пользователей.
#
# *   **Стратегии для удержания пользователей:**
#
#     *   *Фокус на популярных категориях:* Для удержания пользователей, склонных к снижению активности, важно предлагать привлекательные и персонализированные предложения в категориях "Товары для детей", "Домашний текстиль" и "Косметика и аксессуары". Это может включать в себя эксклюзивные акции, скидки, новинки и рекомендации, основанные на их предыдущих покупках.

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=data_segment, x='тип_сервиса', palette='crest',
                   order=data_segment['тип_сервиса'].value_counts().index)

plt.title('Распределение пользователей по типам сервисов', fontsize=14)
plt.xlabel('Тип сервиса', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()

for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height / total_users)
    count = int(height)
    label = f'{count}\n({percentage})'
    x = p.get_x() + p.get_width() / 2
    y = height / 2
    ax.text(x, y, label, ha='center', va='center', color='white', fontsize=12)

plt.show()

# %% [markdown]
# **Выводы по сегменту пользователей, склонных к снижению активности (на основе анализа используемых типов сервисов):**
#
# *   **Преобладающий тип сервиса:** Большинство пользователей, склонных к снижению активности, используют "Стандартный" тип сервиса (61.6%).
#
# *   **Меньшая доля "Премиум" пользователей:** Меньшая часть сегмента использует "Премиум" тип сервиса (38.4%).
#
# *   **Рекомендации по удержанию пользователей:**
#
#     *   **Повышение ценности "Стандартного" сервиса:** Для удержания пользователей, использующих "Стандартный" тип сервиса, необходимо улучшить его ценность. Это может включать в себя добавление новых функций, предоставление дополнительных скидок или бонусов, а также повышение качества обслуживания.
#
#     *   **Стимулирование перехода на "Премиум":**  Рассмотреть возможности стимулирования перехода пользователей со "Стандартного" типа сервиса на "Премиум". Это может включать в себя предоставление пробного периода "Премиум", специальные предложения для апгрейда, а также демонстрацию преимуществ "Премиум" сервиса.
#
#     *   **Анализ причин выбора "Стандартного":** Необходимо понять, почему большая часть сегмента предпочитает "Стандартный" тип сервиса. Возможно, "Премиум" сервис кажется слишком дорогим, или же его преимущества не достаточно очевидны для пользователей.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data_segment, x='неоплаченные_продукты_штук_квартал', kde=True)
plt.title('Распределение неоплаченных продуктов за квартал', fontsize=14)
plt.xlabel('Количество неоплаченных продуктов за квартал', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=data_segment, x='неоплаченные_продукты_штук_квартал', palette='viridis',
                   order = data_segment['неоплаченные_продукты_штук_квартал'].value_counts().index)

plt.title('Распределение пользователей по неоплаченным продуктам за квартал', fontsize=14)
plt.xlabel('Количество неоплаченных продуктов за квартал', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()

total_users = len(data_segment)
for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height / total_users)
    count = int(height)
    label = f'{count}\n({percentage})'
    x = p.get_x() + p.get_width() / 2
    y = height / 2
    ax.text(x, y, label, ha='center', va='center', color='white', fontsize=10)

sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# **Выводы по сегменту пользователей, склонных к снижению активности (на основе анализа количества неоплаченных продуктов за квартал):**
#
# Анализ распределения количества неоплаченных продуктов за квартал среди пользователей, склонных к снижению активности, позволяет сделать следующие выводы:
#
# *   **Характерное поведение:** Большинство пользователей из данного сегмента имеют относительно небольшое количество неоплаченных продуктов за квартал. Распределение имеет тенденцию к правосторонней скошенности, где пик приходится на значения 2-4 неоплаченных продукта.
#
# *   **Наиболее распространенные значения:** Наибольшее количество пользователей имеет 4 неоплаченных продукта за квартал (20.5%), за которым следуют 2 неоплаченных продукта (19.2%).
#
# *   **Небольшое количество с большим количеством неоплаченных продуктов:** Лишь небольшая часть пользователей имеет большое количество неоплаченных продуктов (более 6).
#
# *   **Рекомендации:**
#
#     *   **Таргетированные предложения:** Разработать таргетированные предложения или программы лояльности для пользователей, которые имеют от 2 до 4 неоплаченных продуктов за квартал. Это может способствовать увеличению количества оплат и удержанию этих пользователей.
#
#     *   **Анализ причин неоплаты:** Провести анализ причин, по которым пользователи не оплачивают продукты. Это может быть связано с проблемами оплаты, отсутствием интереса к продукту, или же временными финансовыми трудностями.
#
#     *   **Индивидуальный подход:** Для пользователей с большим количеством неоплаченных продуктов следует применять индивидуальный подход, чтобы понять причины неоплаты и предложить решения, соответствующие их потребностям.

# %% [markdown]
# <div style="background-color:#f5f0f7; padding: 15px; border-radius: 5px; margin-bottom: 10px;">
#
# ### <span style="color:#8B008B">Общий вывод по сегменту пользователей, склонных к снижению активности (с прибылью выше медианной и находящихся в зоне риска)</span>
#
# <p>Данный анализ сфокусирован на пользователях, склонных к снижению активности, чья прибыль выше медианной и которые находятся только в зоне риска и с высокой вероятностью снижения активности.</p>
#
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: none;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">Акционные покупки:</span> Большинство пользователей в данном сегменте редко совершают покупки по акциям (68.5%). Это указывает на необходимость персонализации акционных предложений и выявления причин, по которым акции не привлекают данную группу.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">Предпочитаемые категории:</span> Сегмент проявляет выраженный интерес к категориям "Товары для детей" (26.0%), "Домашний текстиль" (23.3%) и "Косметика и аксессуары" (23.3%).
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">Тип сервиса:</span> Большинство пользователей предпочитают "Стандартный" тип сервиса (61.6%).
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <span style="font-weight:bold">Неоплаченные продукты:</span> Большинство пользователей имеют небольшое количество неоплаченных продуктов за квартал.
#     </li>
# </ul>
#
# <br>
#
#  <span style="font-size: 1.2em; font-weight: bold;">Бизнес-решения (для высокодоходных пользователей в зоне риска):</span>
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: disc;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Персонализированные предложения для удержания:</b> Разработать индивидуальные программы лояльности и предложения, учитывая интересы пользователей и их историю покупок.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Приоритизированная поддержка:</b> Обеспечить высококачественную и быструю поддержку для решения любых вопросов или проблем, которые могут возникнуть у этих пользователей.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b> Стимулирование перехода на "Премиум": </b> Предлагать пробные периоды, специальные условия для апгрейда и демонстрировать преимущества "Премиум" сервиса.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Обратная связь и опросы:</b> Регулярно проводить опросы и собирать обратную связь от этих пользователей, чтобы понять их потребности и ожидания.
#     </li>
# </ul>
#
# <br>
#
#  <span style="font-size: 1.2em; font-weight: bold;">Анализ для повышения лояльности высокодоходных пользователей:</span>
# <ul style="margin-left: 20px; padding-left: 20px; list-style-type: disc;">
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Сегментация внутри сегмента:</b> Провести более глубокую сегментацию внутри данного сегмента (высокодоходные пользователи в зоне риска), чтобы выявить различные группы и адаптировать предложения под их нужды.
#     </li>
#     <li style="margin-bottom: 5px; line-height: 1.3;">
#         <b>Оценка эффективности программ лояльности:</b> Проанализировать эффективность существующих программ лояльности и внести коррективы, чтобы повысить их привлекательность для высокодоходных пользователей.
#     </li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="border: 2px solid blue; padding: 10px; border-radius: 5px; background-color: #f0f8ff;">
# <h2 style="color: blue;">Общий вывод по проекту</h2>
#
# <p style="color: blue; font-weight: bold;">Описание задачи</p>
# <p>Целью данного проекта было проведение всестороннего анализа пользовательских данных для выявления скрытых закономерностей в поведении пользователей. На основе этих закономерностей планировалось разработать конкретные и эффективные рекомендации, направленные на повышение активности пользователей на платформе и их долгосрочное удержание. Ключевыми задачами стали:</p>
# <ul>
#     <li><b>Сегментация пользователей:</b> Разделение пользовательской базы на группы с общими характеристиками и потребностями.</li>
#     <li><b>Оценка факторов влияния:</b> Определение факторов, оказывающих наибольшее влияние на покупательскую активность.</li>
#     <li><b>Построение предсказательных моделей:</b> Разработка моделей машинного обучения, способных предсказывать пользователей, наиболее склонных к снижению активности (оттоку).</li>
# </ul>
#
# <p style="color: blue; font-weight: bold;">Исходные данные и проведённая предобработка</p>
# <p>Исходные данные для анализа были представлены в виде четырех взаимосвязанных файлов: `market_file`, `market_money`, `market_time` и `money`. Эти файлы содержали подробную информацию о профилях пользователей, их транзакциях, времени, проведенном на платформе, и общих финансовых показателях.  Предобработка данных включала следующие этапы:</p>
# <ul>
#     <li><b>Стандартизация наименований столбцов:</b> Приведение всех названий столбцов к единому "змеиному" стилю для обеспечения консистентности и удобства работы.</li>
#     <li><b>Коррекция ошибок и опечаток:</b> Исправление выявленных ошибок в данных, в частности в столбцах, описывающих "тип сервиса" и "период" использования.</li>
#     <li><b>Анализ аномальных значений:</b>  Тщательная проверка данных на наличие аномалий, таких как нулевая выручка и чрезмерно высокие значения выручки в таблице `market_money`, с целью выявления потенциальных ошибок или выбросов.</li>
#     <li><b>Удаление дубликатов:</b>  Проверка данных на наличие полных или частичных дубликатов для обеспечения точности анализа (дубликаты обнаружены не были).</li>
# </ul>
# <p>После завершения этапа предобработки данные были полностью готовы к дальнейшему анализу и построению моделей машинного обучения.</p>
#
# <p style="color: blue; font-weight: bold;">Поиск лучшей модели</p>
# <p>Для достижения максимальной точности предсказания оттока пользователей был проведен сравнительный анализ нескольких алгоритмов машинного обучения. В частности, были протестированы следующие модели:</p>
# <ul>
#     <li><b>`DecisionTreeClassifier`</b></li>
#     <li><b>`KNeighborsClassifier`</b></li>
#     <li><b>`LogisticRegression`</b></li>
#     <li><b>`SVC`</b></li>
# </ul>
# <p>Для оценки эффективности каждой модели была использована метрика ROC-AUC, которая является особенно полезной в задачах с несбалансированными классами (когда одна категория значительно преобладает над другой). ROC-AUC позволяет оценить способность модели различать между положительными и отрицательными примерами вне зависимости от порога классификации.</p>
#
# <p style="color: blue; font-weight: bold;">Лучшая модель</p>
# <p>По результатам тестирования, наилучшие результаты продемонстрировала модель <b>`LogisticRegression`</b>.  На тестовой выборке модель достигла значения ROC-AUC равного 0.8799 при оптимальных значениях гиперпараметров: `C=1`, `penalty='l1'`, `solver='liblinear'`. Это указывает на высокую способность модели к точной классификации пользователей, склонных к оттоку.  Выбранные гиперпараметры позволили достичь баланса между точностью и обобщающей способностью модели, минимизируя риск переобучения.</p>
#
# <p style="color: blue; font-weight: bold;">Выводы и дополнительные предложения для выбранного сегмента покупателей</p>
# <p>Особую группу риска составляют пользователи, которые редко совершают покупки по акциям и специальным предложениям.  Для этого сегмента, который характеризуется прибылью выше медианной и одновременным нахождением в зоне риска оттока, были разработаны следующие рекомендации:</p>
# <ul>
#     <li><b>Персонализированные предложения для удержания:</b> Разработка индивидуальных программ лояльности и предложений, учитывающих уникальные интересы, историю покупок и предпочтения каждого пользователя. Это может включать в себя эксклюзивные скидки на товары, которыми пользователь ранее интересовался, персональные рекомендации и поздравления с праздниками.</li>
#     <li><b>Приоритизированная поддержка:</b> Обеспечение высококачественной и оперативной поддержки пользователей этого сегмента. Это может включать в себя выделенную линию поддержки, персонального менеджера или приоритетную обработку запросов. Цель – быстрое и эффективное решение любых возникающих вопросов и проблем.</li>
#     <li><b>Стимулирование перехода на "Премиум":</b> Предложение пользователям этого сегмента попробовать "Премиум" сервис на льготных условиях. Это может включать в себя бесплатный пробный период, специальные цены на апгрейд и демонстрацию всех преимуществ "Премиум" подписки (например, расширенный функционал, приоритетный доступ к новым функциям и т.д.).</li>
#     <li><b>Обратная связь и опросы:</b> Регулярный сбор обратной связи от пользователей этого сегмента через опросы, интервью и другие каналы. Важно выяснить, что именно не устраивает пользователей, какие у них есть пожелания и как можно улучшить сервис.</li>
# </ul>
#
# <p>В заключение, проведенный анализ и предложенные рекомендации представляют собой комплексный подход к повышению лояльности и активности пользователей, находящихся в зоне риска оттока. Реализация этих мер позволит не только снизить отток, но и увеличить общую выручку платформы за счет удержания ценных клиентов и стимулирования их к дальнейшему использованию сервиса.</p>
# </div>
